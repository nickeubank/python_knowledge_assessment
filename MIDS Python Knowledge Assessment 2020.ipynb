# %% [markdown]
# # MIDS Python Knowledge Assessment 2020 (70 minutes)
#
# ## READ THIS CAREFULLY
#
# This is not a test; it is a diagnostic knowledge assessment. It's purpose is to see (a) whether you should skip Practical Data Science, and (b) if not, what you have absorbed from summer coursework so I know what to emphasize in my course this fall. To accomplish this, the assessment includes questions that cover much of the material that will be covered in Practical Data Science -- material you were *not* taught over the summer.
#
# These questions are designed to identify students with prior experience with Python who don't need to take Practical Data Science, so I don't expect most students to be able to do those portion of the exam. I don't think it would be unreasonable for a student without prior Python experience who worked hard this summer to only correctly answer about 30% of the questions here -- and that's **fine!**. Again, the point of this assessment is not to grade you, but rather to help me figure out what you know so that I can tailor my course materials *to meet you where you are*, and best support your training moving forward.
#
# That also means that if you don't know how to do something, **please don't spend all your time trying to figure it out!**. There *will* be questions you don't know how to do, so when you find one, just move on!

# %% [markdown]
# ## Closed Book Portion (10 minutes)
#
# For this portion of the exam, please **DO NOT** use your computers, just write your answers with a pen or pencil. You should only spend 10 minutes on this section.
#
# **Note:** I recognize it would be easy for you to cheat given you're taking this from home, and as a general policy I will never give you graded closed book exams (it just creates too much pressure to cheat). However, this is NOT an exam, and is not graded, so if you cheat the only person it will hurt is you because it will give us bad information about what you know and don't know, leading to us giving you poor guidance about courses. So please don't cheat!

# %% [markdown]
# **(1)** Consider the following code:
#
# ```python
# x = 0
# for i in range(5):
#     x = x + i
# print(x)
# ```
#
# What will Python print out at the end of this code?
#
#
# ```
#
#
#
#
#
#
# ```
#
#
#
# **(2)** Consider the following code:
#
# ```python
# x = [1, 2, 3]
# y = x
#
# x.append(4)
# # Note: `.append(4)` will add the number 4 as the last entry
# # in the list associated with x.
#
# print(y)
# ```
#
# What will Python print out at the end of this code?
#
# ```
#
#
#
#
#
#
# ```
#
#
#
#
# **(3)** Consider the following code:
#
# ```python
# x = 'this is a string'
# y = x
# x = x.upper()
# print(y)
# ```
#
# What will Python print out at the end of this code?
#
# ```
#
#
#
#
#
#
# ```
#
# **(4)** What is your pre-MIDS experience with Python?
#
# ```
#
#
#
#
#
#
# ```
#
# **(5)** What is your pre-MIDS experience with pandas?
#
#
# ```
#
#
#
#
#
#
# ```

# %% [markdown]
# ## Open Book Portion (60 Minutes)
#
# **For this part of the exam, please use your computer and Python to answer the following questions**
#
# ### Using the Internet
#
# You are welcome to use the internet for this portion of the exam. However, the *only* time I would advise using the internet is if you know what you want to do but just can't quite remember the right syntax for doing it. Do **not** try to use the internet to figure out something you don't know -- you will waste far more time browsing the web, and will end up with a lower score than if you just skipped the question!

# %% [markdown]
# ## Part 2: Basic Python

# %% [markdown]
# **(6)** What is the type of the variable x defined as `x = "42"`?
#
#
# ```
#
#
# ```

# %% [markdown]
# **(7)** Consider the list `my_list = [42, 47, 1.168, 3.14, 8, -5]`. What code would return the *second* and *third* entries of `my_list`?
#
# ```
#
#
# ```

# %% [markdown]
# **(8)** What code would return the last entry of `my_list`?
#
# ```
#
#
# ```

# %% [markdown]
# **(9)** What is the value of $\frac{5^{3}}{12 * 5}$ (rounded to two decimal places)
#
# ```
#
#
# ```

# %% [markdown]
# **(10)** Add up all the odd numbers from 1 to 153 (e.g. 1, 2, 3, ... , 150, 151, 153).
#
#
# ```
#
#
# ```

# %% [markdown]
# ## Part 3: Basic Data Analysis
# Below, you're given code to generate a list of 500 random integers. Use that list to answer the following questions.

# %%
# Generate the 500 random numbers [DO NOT MODIFY THIS CODE]
import numpy as np
np.random.seed(14) # This guarantees the code will generate the same set of random numbers whenever executed
random_integers = np.random.randint(1,high=500000, size=(500))

print(random_integers)
# Out:
# [117356  79193 402701 117143 285000 306938 482663 340715 187037 489099
#  361681 301630 237033 384878 202395 455706  66008 310263 272876 121377
#  364536 164101 393166 244875 302731  79361  61911 236629 243846 376358
#  271993 313446 268330 493289 426216   8772 427728  95557 332750 273582
#   68988  16146 130812 185335 153473 224416 213770 365756  49180 103414
#  172251 436012 294647  75763 274690   3965 348488 178281 490176 370571
#  100398 417520 305183 447380 386626 404538 385612 153806 211282 342374
#   60174 338873 423248 214698 168576 476438  43534 254276 165950 274763
#   65263 386490 268751  57949 343279 450493 298506   4431 211333 108723
#  270822 481845  16642 329868 165861 405362 323972 471053 211869  81750
#  313833 134546  79188 270712 137777 354212 274024 298962 291211  74549
#    3903 306390 288309 201028 494905 447463 403450 144433 423241 433646
#  112309 152164 285783 194007 463801 474381 306739   9276 452346 230477
# ...

# %% [markdown]
# **(11)** What is the difference between the largest and the smallest number in this list?
#
#
# ```
#
#
# ```
#
# **(12)** What is the mean of this list (to two decimal places)?
#
#
# ```
#
#
# ```
#
# **(13)** How many of the numbers in the list are multiples of 251? For example, since 251\*2 = 502, then 502 is a multiple of 251.
#
#
# ```
#
#
# ```
#
# **(14)** What is the mean of the odd values in this list (to two decimal places)?
#
#
# ```
#
#
# ```

# %% [markdown]
# ## Part 3: Implementing Equations
#
# **(15)** Implement the following equation as Python code, and determine what its value is for $x=1$. What is the value of $y$ to 2 decimal places?
#
# $$y = 4\sum_{n=0}^{10^6} \frac{(-1)^n}{2n+1}x^{2n+1}$$
#
# *Hint: if all goes well, you should see a familiar number*
#
#
# ```
#
#
# ```

# %% [markdown]
# ## Part 4: Loading data and answering questions for a real dataset
#
#
# For this part, we'll be using data on US power plants that you can download from this url: [https://bit.ly/2Mlt8lR](https://bit.ly/2Mlt8lR) (that code is the number 2, capital M, lower case L, lower case t, the number 8, lower case L, capital R). The file is a comma-separated value spreadsheet (CSV) called `egrid2016.csv`.
#
# This is the dataset we'll be exploring through the following exercises. This dataset is the Environmental Protection Agency's (EPA) [Emissions & Generation Resource Integrated Database (eGRID)](https://www.epa.gov/energy/emissions-generation-resource-integrated-database-egrid) containing information about all power plants in the United States, the amount of genereration they produce, what fuel they use, the location of the plant, and many more quantities. We'll be using a subset of those data.
#
# The fields we'll be using include:
#
# |field    |description|
# |:-----   |:-----|
# |SEQPLT16 |eGRID2016 Plant file sequence number (the index)|
# |PSTATABB |Plant state abbreviation|
# |PNAME    |Plant name |
# |PLPRMFL  |Plant primary fuel |
# |CAPFAC   |Plant capacity factor |
# |NAMEPCAP |Plant nameplate capacity (Megawatts MW)|
# |PLNGENAN |Plant annual net generation (Megawatt-hours MWh)|
# |PLCO2EQA |Plant annual CO2 equivalent emissions (tons)|
#
#
# ### Analyzing the CSV
#
# For this CSV dataset, your goal is answer the following questions about electricity generation in the United States:
#
# **(16)** Which plant has generated the most energy (measured in MWh)?
#
#
# ```
#
#
# ```
#
# **(17)** What plant has the highest annual CO2 emissions?
#
# *Note: there's a trick to this, so if you get stuck and don't immediately understand the problem, just move on*
#
# ```
#
#
# ```
#
# **(18)** What state has the second largest power plant (by average annual net generation) in the country?
#
# ```
#
#
#
# ```
#
# **(19)** What state has the highest average annual net generation for all its power plants?
#
# ```
#
#
#
#
#
# ```

# %% [markdown]
# ### Merging in Location Data
#
# For these next questions, download the file egrid2016_locations.xlsx from [https://bit.ly/2YSReuR](https://bit.ly/2YSReuR) (that's two, capital Y, capital S, capital R, lower case e, lower case u, capital R), then merge that dataset with the data you are already using on the variable `SEQPLT16`.
#
# Note that the headers for this datadset are on the second row and you'll want to ignore the first row (they're more detailed descriptions of the headers).
#
# **(20)** What is the name of the northern-most power plant in the United States (i.e. the plant with this highest value of latitude (`LAT`)?
#
# ```
#
#
# ```
#
# **(21)** What is the state where the northern-most power plant in the United States is located?
#
# ```
#
#
#
# ```
